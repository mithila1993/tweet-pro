# %%
from selenium import webdriver
import shutil
import requests
import codecs
import re

# %%
driver = webdriver.Chrome(executable_path=r'E:/Project - Level 4/chromedriver_win32/chromedriver.exe' )
driver.get('https://mbasic.facebook.com')

# %%
email = driver.find_element_by_id("m_login_email")
email.send_keys('k_kithsiri@yahoo.com\t')

password = driver.find_element_by_xpath('html/body/div/div/div[2]/div/table/tbody/tr/td/div[2]/div[2]/form/ul/li[2]/div/input')
password.send_keys('s+pfYyXU1\n')

# %%
link_file = codecs.open("Links/links.txt", "r", "utf8")
links = link_file.readlines()
link_file.close()

# %%
driver.get(links[0])

# %%
driver2 = driver.find_element_by_xpath('//*[@id="m_group_stories_container"]/div[1]');
list = driver2.find_elements_by_xpath("//div");
for x in list:
    print(x.text)
# Out:
# HomeProfileMessagesNotificationsChatFriendsPages(32)Groups(99)
# Menu
# Online හෙල්ප්
# Private group
# Member
# Write something...
#   Announcements
# See All (6)
# Krishan Buddhika > Online හෙල්ප්
# 😍FREE 😍FREE😍 NORDVPN PREMIUM 😍FREE 😍FREE😍
# අද (09) දිනයේ සිට ඉදිරියට ඔබ අපෙන් මිලදී ගන්නා රුපියල් 500කට වැඩි ඕනෑම මිලදී ගැනීමකට අපෙන් ඔබට NORDVPN PREMIUM එකවුන්ට් එකක් නොමිලේ. වැඩි විස්තර 071 1 578 578 DVDHIVE.LK
# මෙම දීමනාව සීමිත කාලයක් සඳහා පමණි. (*කොන්දේසි සහිතයි)
# August 9 at 4:51 PM
# 75 · Like · React · 16 Comments · Full Story · Save · More
# New Activity
# Rukshan Dammika shared a post.
# නිරෝගා
# 15 hrs
# 821 · Like · React · 47 Comments · Full Story · Save · More
# Ruwan Rajapaksha > Online හෙල්ප්
# 🚗 කාර් එකක් පොලිෂ් කරගන්ඩ හොදම පොලිෂ් එක මොකක්ද සුපිරියට දිස්නේ එන එකක්
# 10 hrs
# 32 · Like · React · 20 Comments · Full Story · Save · More
# Suggested Groups
# FRIENDS GROUP
# Kasun Vithanage and 3 other friends have joined
# Join
# ඉලෙක්ට්‍රොනික් වැඩකාරයෝ
# 28,471 members
# ...
