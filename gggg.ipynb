# %%
#import xlwt
import GetOldTweets3 as got
import winsound
from openpyxl import Workbook
import datetime

# %%
wb = Workbook()
ws = wb.active

# startDate1 = "2019-01-0"
# startDate2 = "2019-01-"
startDate = ''
querySearchTerm = "tourism"
tweetLimit = 4000
counter = 1

# %%
def getTweets(startDate,endDate):
    print(datetime.datetime.now().time(),startDate,endDate)
    global counter

    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(querySearchTerm)\
                                               .setSince(startDate)\
                                               .setUntil(endDate)\
                                               .setMaxTweets(tweetLimit)

    for index,x in enumerate(got.manager.TweetManager.getTweets(tweetCriteria)):
        
        datestring = str(x.date)
        type = datestring +' | ' + x.text +' | ' + x.id
        stringExcel = str(type)
        
        ws.cell(counter, 1, stringExcel)
        counter += 1

# %%
getTweets("2018-06-27","2018-06-28")
wb.save('2018-06-27.xlsx')
getTweets("2018-06-28","2018-06-29")
wb.save('2018-06-28.xlsx')
getTweets("2018-06-29","2018-06-30")
wb.save('2018-06-29.xlsx')
getTweets("2018-06-30","2018-06-31")
wb.save('2018-06-30.xlsx')


getTweets("2018-07-01","2018-07-02")
wb.save('2018-07-01.xlsx')
getTweets("2018-07-02","2018-07-03")
wb.save('2018-07-02.xlsx')
getTweets("2018-07-03","2018-07-04")
wb.save('2018-07-03.xlsx')
getTweets("2018-07-04","2018-07-05")
wb.save('2018-07-04.xlsx')
getTweets("2018-07-05","2018-07-06")
wb.save('2018-07-05.xlsx')
getTweets("2018-07-06","2018-07-07")
wb.save('2018-07-06.xlsx')
getTweets("2018-07-07","2018-07-08")
wb.save('2018-07-07.xlsx')
getTweets("2018-07-08","2018-07-09")
wb.save('2018-07-08.xlsx')
getTweets("2018-07-09","2018-07-10")
wb.save('2018-07-09.xlsx')
getTweets("2018-07-10","2018-07-11")
wb.save('2018-07-10.xlsx')
getTweets("2018-07-11","2018-07-12")
wb.save('2018-07-11.xlsx')
getTweets("2018-07-12","2018-07-13")
wb.save('2018-07-12.xlsx')
getTweets("2018-07-13","2018-07-14")
wb.save('2018-07-13.xlsx')
getTweets("2018-07-14","2018-07-15")
wb.save('2018-07-14.xlsx')
getTweets("2018-07-15","2018-07-16")
wb.save('2018-07-15.xlsx')
getTweets("2018-07-16","2018-07-17")
wb.save('2018-07-16.xlsx')
getTweets("2018-07-17","2018-07-18")
wb.save('2018-07-17.xlsx')
getTweets("2018-07-18","2018-07-19")
wb.save('2018-07-18.xlsx')
getTweets("2018-07-19","2018-07-20")
wb.save('2018-07-19.xlsx')
getTweets("2018-07-20","2018-07-21")
wb.save('2018-07-20.xlsx')
getTweets("2018-07-21","2018-07-22")
wb.save('2018-07-21.xlsx')
getTweets("2018-07-22","2018-07-23")
wb.save('2018-07-22.xlsx')
getTweets("2018-07-23","2018-07-24")
wb.save('2018-07-23.xlsx')
getTweets("2018-07-24","2018-07-25")
wb.save('2018-07-24.xlsx')
getTweets("2018-07-25","2018-07-26")
wb.save('2018-07-25.xlsx')
getTweets("2018-07-26","2018-07-27")
wb.save('2018-07-26.xlsx')
getTweets("2018-07-27","2018-07-28")
wb.save('2018-07-27.xlsx')
getTweets("2018-07-28","2018-07-29")
wb.save('2018-07-28.xlsx')
getTweets("2018-07-29","2018-07-30")
wb.save('2018-07-29.xlsx')
getTweets("2018-07-30","2018-07-31")
wb.save('2018-07-30.xlsx')


getTweets("2018-08-01","2018-08-02")
wb.save('2018-08-01.xlsx')
getTweets("2018-08-02","2018-08-03")
wb.save('2018-08-02.xlsx')
getTweets("2018-08-03","2018-08-04")
wb.save('2018-08-03.xlsx')
getTweets("2018-08-04","2018-08-05")
wb.save('2018-08-04.xlsx')
getTweets("2018-08-05","2018-08-06")
wb.save('2018-08-05.xlsx')
getTweets("2018-08-06","2018-08-07")
wb.save('2018-08-06.xlsx')
getTweets("2018-08-07","2018-08-08")
wb.save('2018-08-07.xlsx')
getTweets("2018-08-08","2018-08-09")
wb.save('2018-08-08.xlsx')
getTweets("2018-08-09","2018-08-10")
wb.save('2018-08-09.xlsx')
getTweets("2018-08-10","2018-08-11")
wb.save('2018-08-10.xlsx')
getTweets("2018-08-11","2018-08-12")
wb.save('2018-08-11.xlsx')
getTweets("2018-08-12","2018-08-13")
wb.save('2018-08-12.xlsx')
getTweets("2018-08-13","2018-08-14")
wb.save('2018-08-13.xlsx')
getTweets("2018-08-14","2018-08-15")
wb.save('2018-08-14.xlsx')
getTweets("2018-08-15","2018-08-16")
wb.save('2018-08-15.xlsx')
getTweets("2018-08-16","2018-08-17")
wb.save('2018-08-16.xlsx')
getTweets("2018-08-17","2018-08-18")
wb.save('2018-08-17.xlsx')
getTweets("2018-08-18","2018-08-19")
wb.save('2018-08-18.xlsx')
getTweets("2018-08-19","2018-08-20")
wb.save('2018-08-19.xlsx')
getTweets("2018-08-20","2018-08-21")
wb.save('2018-08-20.xlsx')
getTweets("2018-08-21","2018-08-22")
wb.save('2018-08-21.xlsx')
getTweets("2018-08-22","2018-08-23")
wb.save('2018-08-22.xlsx')
getTweets("2018-08-23","2018-08-24")
wb.save('2018-08-23.xlsx')
getTweets("2018-08-24","2018-08-25")
wb.save('2018-08-24.xlsx')
getTweets("2018-08-25","2018-08-26")
wb.save('2018-08-25.xlsx')
getTweets("2018-08-26","2018-08-27")
wb.save('2018-08-26.xlsx')
# Out:
# 07:56:46.775997 2018-06-27 2018-06-28
# 08:02:17.686608 2018-06-28 2018-06-29
# 08:07:48.169994 2018-06-29 2018-06-30
# 08:13:29.087496 2018-06-30 2018-06-31
# 08:13:30.840627 2018-07-01 2018-07-02
# 08:18:54.559149 2018-07-02 2018-07-03
# 08:24:26.392454 2018-07-03 2018-07-04
# 08:29:53.729888 2018-07-04 2018-07-05
# 08:35:46.883064 2018-07-05 2018-07-06
# 08:41:15.284788 2018-07-06 2018-07-07
# 08:47:10.705650 2018-07-07 2018-07-08
# 08:52:42.543420 2018-07-08 2018-07-09
# 08:59:45.897098 2018-07-09 2018-07-10
# 09:05:45.552222 2018-07-10 2018-07-11
# 09:11:25.080605 2018-07-11 2018-07-12
# 09:17:07.857506 2018-07-12 2018-07-13
# 09:22:28.288639 2018-07-13 2018-07-14
# 09:28:12.743415 2018-07-14 2018-07-15
# 09:34:11.863006 2018-07-15 2018-07-16
# 09:39:52.142051 2018-07-16 2018-07-17
# 09:45:17.976312 2018-07-17 2018-07-18
# 09:50:40.677122 2018-07-18 2018-07-19
# 09:56:02.011165 2018-07-19 2018-07-20
# 10:01:39.328496 2018-07-20 2018-07-21
# 10:07:06.916168 2018-07-21 2018-07-22
# ...
